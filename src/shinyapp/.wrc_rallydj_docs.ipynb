# %% [markdown]
# # `wrc-rallydj` Docs
#
# Examples of working with `wrc-rallydj` package.

# %%
from wrc_rallydj.livetiming_api import WRCLiveTimingAPIClient

wrc = WRCLiveTimingAPIClient(use_cache=True, backend="memory", expire_after=600)

# Current year, latest race by default, wrc class
wrc.initialise()

# %%
wrc.championship
# Out:
# 'wrc'

# %%
wrc.full_calendar
# TO DO - countries pull into own table
# pull out seasonId
# Out:
#       id         guid                           title                location  \
# 0   K1Lg  WRC_2025_01              Rallye Monte-Carlo                  Monaco
# 1   skC3  WRC_2025_02               WRC Rally Sweden                   sweden
# 2   G2NQ  WRC_2025_03          WRC Safari Rally Kenya         Naivasha, Kenya
# 3   zhuM  WRC_2025_04        WRC Rally Islas Canarias   Islas Canarias, Spain
# 4   edGQ  WRC_2025_05  WRC Vodafone Rally de Portugal       Matosinhos, Porto
# 5   k5hf  WRC_2025_06       WRC Rally Italia Sardegna         Olbia, Sardinia
# 6   eaYx  WRC_2025_07  WRC EKO Acropolis Rally Greece                   Lamia
# 7   aIpJ  WRC_2025_08         WRC Delfi Rally Estonia                 Estonia
# 8   CaGI  WRC_2025_09         WRC Secto Rally Finland               Jyväskylä
# 9   nMcx  WRC_2025_10          WRC Rally del Paraguay                Paraguay
# 10  XpJ0  WRC_2025_11         WRC Rally Chile Bio Bío              Concepcion
# ...

# %%
wrc.full_calendar.iloc[0]['country']["iso3"]
# Out:
# 'MCO'

# %%
wrc.full_calendar.iloc[0]["season"]
# Out:
# {'id': '966f4272-df7f-41af-8686-7c5b8fd1dca1',
#  'name': None,
#  'seasonId': '34',
#  'title': '2025',
#  '__typename': 'Season'}

# %%
wrc.full_calendar.iloc[0]["asset"]
# Out:
# {'id': 'w29008',
#  'contents': [{'id': '714992b4-5036-47fe-be4f-9f7d03a274ef',
#    '__typename': 'ContentItem'},
#   {'id': '86d6a7d5-9fa0-4bc7-abe8-3df27df2062b', '__typename': 'ContentItem'},
#   {'id': 'dfaca39e-bf23-40a7-8a19-2f861a5fbcb4', '__typename': 'ContentItem'},
#   {'id': 'f74c712e-821e-4d79-bd4e-203ffa501930', '__typename': 'ContentItem'},
#   {'id': '74a4bac2-2c10-4278-b44a-20702617c74b', '__typename': 'ContentItem'},
#   {'id': '4b09b3f7-b817-46bc-ae66-c207ebefdb4b', '__typename': 'ContentItem'}],
#  '__typename': 'Asset'}

# %%
wrc.full_calendar.iloc[0]["competition"]
# Out:
# {'id': '9d47f7e5-e7b9-4ef2-a72e-f868dc80c47b',
#  'title': 'WRC',
#  'competitionId': 'wrc',
#  'logo': {'id': '819869eb-5e61-3a39-9245-257dacc333d6',
#   'fileName': 'https://wrc.enhance.diagnal.com/resources/static/c0fa9cc1-9739-4412-ab53-b1cf67929866_wrc.png',
#   'dimensions': {'height': 236, 'width': 408, '__typename': 'ImageDimenstion'},
#   'aspectRatio': [{'title': '2:1',
#     'resolutions': [{'id': 'bf7e877e-c6e0-5b14-9795-c6065158df36',
#       'url': 'https://wrc.enhance.diagnal..../c0fa9cc1-9739-4412-ab53-b1cf67929866_wrc.png',
#       'height': 960,
#       'width': 1920,
#       '__typename': 'Resolution'}],
#     '__typename': 'AspectRatio'},
#    {'title': '4:5',
#     'resolutions': [{'id': '6ae0d033-897b-5465-b0b6-ce47c535a0d8',
#       'url': 'https://wrc.enhance.diagnal..../c0fa9cc1-9739-4412-ab53-b1cf67929866_wrc.png',
#       'height': 400,
#       'width': 320,
#       '__typename': 'Resolution'},
#      {'id': 'dfab48fa-c505-5c1c-8f26-9836a25b6ee6',
# ...
